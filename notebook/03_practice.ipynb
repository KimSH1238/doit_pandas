# %%
# 시리즈 만들기

import pandas as pd
s=pd.Series(["banana",42])
print(s)
print()

# 문자열을 인덱스로 지정할 수 있으며, 시리즈 메서드의 인덱스 인자를 통해 리스트에 담아 전달
s=pd.Series(["Wes McKinney","Creator of Pandas"])
print(s)
print()

s=pd.Series(["Wes McKinney","Creator of Pandas"], index=["person","Who"])
print(s)
# Out:
# 0    banana
# 1        42
# dtype: object
#
# 0         Wes McKinney
# 1    Creator of Pandas
# dtype: object
#
# person         Wes McKinney
# Who       Creator of Pandas
# dtype: object

# %% [markdown]
# #
# 시리즈 완료 후, 데이터프레임 만들기

# %%
scientists=pd.DataFrame({
    "Name":["Rosaline Franklin","William Gosset"],
    "Occupation":["Chemist","Statistician"],
    "Age":[37,61]}
)
print(scientists)
print()

from collections import OrderedDict
scientists=pd.DataFrame(OrderedDict([
    ("Name",["Rosaline Franklin","William Gosset"]),
    ("Occupation",["Chemist","Statistician"]),
    ("Age",[37,61])
]))
print(scientists)
# Out:
#                 Name    Occupation  Age
# 0  Rosaline Franklin       Chemist   37
# 1     William Gosset  Statistician   61
#
#                 Name    Occupation  Age
# 0  Rosaline Franklin       Chemist   37
# 1     William Gosset  Statistician   61

# %% [markdown]
# #
# 데이터프레임에서 시리즈 선택하기

# %%
scientists=pd.DataFrame({
    "Occupation":["Chemist","Statistician"],
    "Age":[37,61]},
index=["Rosaline Franklin","William Gosset"],
columns=["Occupation","Age"]
)
print(scientists)
print()

first_row=scientists.loc["William Gosset"]
print(first_row)
print(type(first_row))
# Out:
#                      Occupation  Age
# Rosaline Franklin       Chemist   37
# William Gosset     Statistician   61
#
# Occupation    Statistician
# Age                     61
# Name: William Gosset, dtype: object
# <class 'pandas.core.series.Series'>

# %% [markdown]
# #
# index, values, keys 사용하기

# %%
import pandas as pd
print(first_row.index)
print(first_row.values)
print()

print(first_row.index[0])
print(first_row.keys()[0])
# Out:
# Index(['Occupation', 'Age'], dtype='object')
# ['Statistician' np.int64(61)]
#
# Occupation
# Occupation

# %% [markdown]
# #
# 시리즈의 mean, min, max, std 메서드 사용하기

# %%
ages=scientists["Age"]
print(ages,"\n")

print(ages.mean())
print(ages.min())
print(ages.max())
print(ages.std())
# Out:
# Rosaline Franklin    37
# William Gosset       61
# Name: Age, dtype: int64
#
# 49.0
# 37
# 61
# 16.97056274847714

# %% [markdown]
# #
# 시리즈와 불린 추출 사용하기

# %%
scientists=pd.read_csv("../data/scientists.csv")
ages=scientists["Age"]
print(ages.max())
print(ages.min())
print(ages.mean())
print(ages.std(),"\n")

#불리언 이용 추출
print(ages[ages>ages.mean()])
# Out:
# 90
# 37
# 59.125
# 18.325918413937288
#
# 1    61
# 2    90
# 3    66
# 7    77
# Name: Age, dtype: int64

# %% [markdown]
# # 시리즈와 브로드캐스팅

# %% [markdown]
# # 데이터프레임과 불린 추출

# %% [markdown]
# # 데이터프레임과 브로드캐스팅

# %% [markdown]
# # 열의 자료형 바꾸기와 새로운 열 추가하기

# %% [markdown]
# # 시리즈, 데이터프레임의 데이터 섞어보기

# %% [markdown]
# # 데이터프레임의 열 삭제하기

# %% [markdown]
# # 피클 형식으로 저장하기

# %% [markdown]
# # CSV 불러오기

# %% [markdown]
# #
# 갭마인더 데이터 집합 불러오기

# %%
print("hello, pandas")
print("hello, pandas,, i want to fix more")

import pandas as pd
df=pd.read_csv('../data/gapminder.tsv', sep="\t")
# Out:
# hello, pandas
# hello, pandas,, i want to fix more

# %% [markdown]
# #
# 불러온 데이터 집합 살펴보기

# %%
import pandas as pd
df=pd.read_csv("../data/gapminder.tsv", sep="\t")
print(df.head())
print("")

import pandas as pd
df=pd.read_csv("../data/gapminder.tsv", sep="\t")

print(type(df))
print("")
print(df.shape)
print("")
print(df.columns)
print("")
print(df.dtypes)
print("")
print(df.info())
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106
#
# <class 'pandas.core.frame.DataFrame'>
#
# (1704, 6)
#
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')
#
# country       object
# continent     object
# year           int64
# lifeExp      float64
# pop            int64
# gdpPercap    float64
# dtype: object
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
# ...

# %% [markdown]
# #
# 열 단위로 데이터 추출하기

# %%
import pandas as pd
df=pd.read_csv("../data/gapminder.tsv", sep="\t")

country_df=df['country']
print(type(country_df))
print("")
print(country_df.head())
print("")
print(country_df.tail())
print("")

subset=df[["country", "continent", "year"]]
print(type(subset))
print("")
print(subset.head())
print("")
print(subset.tail())
# Out:
# <class 'pandas.core.series.Series'>
#
# 0    Afghanistan
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: country, dtype: object
#
# 1699    Zimbabwe
# 1700    Zimbabwe
# 1701    Zimbabwe
# 1702    Zimbabwe
# 1703    Zimbabwe
# Name: country, dtype: object
#
# <class 'pandas.core.frame.DataFrame'>
#
#        country continent  year
# 0  Afghanistan      Asia  1952
# 1  Afghanistan      Asia  1957
# 2  Afghanistan      Asia  1962
# 3  Afghanistan      Asia  1967
# 4  Afghanistan      Asia  1972
#
#        country continent  year
# 1699  Zimbabwe    Africa  1987
# 1700  Zimbabwe    Africa  1992
# 1701  Zimbabwe    Africa  1997
# 1702  Zimbabwe    Africa  2002
# 1703  Zimbabwe    Africa  2007

# %% [markdown]
# #
# loc 속성으로 행 단위 데이터 추출하기

# %%
import pandas as pd
df=pd.read_csv("../data/gapminder.tsv", sep="\t")

print(df.loc[0])
print("")
print(df.loc[90])
print("")

number_of_rows=df.shape[0]
last_row_index=number_of_rows-1
print(df.loc[last_row_index])
print("")

print(df.loc[[1,90]],df.tail(n=1))
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap     779.445314
# Name: 0, dtype: object
#
# country          Bahrain
# continent           Asia
# year                1982
# lifeExp           69.052
# pop               377967
# gdpPercap    19211.14731
# Name: 90, dtype: object
#
# country        Zimbabwe
# continent        Africa
# year               2007
# lifeExp          43.487
# pop            12311143
# gdpPercap    469.709298
# Name: 1703, dtype: object
#
#         country continent  year  lifeExp      pop    gdpPercap
# 1   Afghanistan      Asia  1957   30.332  9240934    820.85303
# 90      Bahrain      Asia  1982   69.052   377967  19211.14731        country continent  year  lifeExp       pop   gdpPercap
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %% [markdown]
# #
# tail과 loc는 조금 달라요!

# %%
subset_loc=df.loc[0]
print(subset)
print("")
subset_tail=df.tail(n=1)

print(type(subset_loc))
print(type(subset_tail))
# Out:
#           country continent  year
# 0     Afghanistan      Asia  1952
# 1     Afghanistan      Asia  1957
# 2     Afghanistan      Asia  1962
# 3     Afghanistan      Asia  1967
# 4     Afghanistan      Asia  1972
# ...           ...       ...   ...
# 1699     Zimbabwe    Africa  1987
# 1700     Zimbabwe    Africa  1992
# 1701     Zimbabwe    Africa  1997
# 1702     Zimbabwe    Africa  2002
# 1703     Zimbabwe    Africa  2007
#
# [1704 rows x 3 columns]
#
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# # iloc 속성으로 행 단위 데이터 추출하기

# %%
print(df.iloc[0])
print("")
print(df.iloc[90])
print("")
print(df.iloc[-1])
print("")
print(df.iloc[[0,90,-1]])

#df.loc[행,렬]이나 df.iloc[행,렬] 도 가능하다.
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap     779.445314
# Name: 0, dtype: object
#
# country          Bahrain
# continent           Asia
# year                1982
# lifeExp           69.052
# pop               377967
# gdpPercap    19211.14731
# Name: 90, dtype: object
#
# country        Zimbabwe
# continent        Africa
# year               2007
# lifeExp          43.487
# pop            12311143
# gdpPercap    469.709298
# Name: 1703, dtype: object
#
#           country continent  year  lifeExp       pop     gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333    779.445314
# 90        Bahrain      Asia  1982   69.052    377967  19211.147310
# 1703     Zimbabwe    Africa  2007   43.487  12311143    469.709298

# %% [markdown]
# #
# 파이썬 슬라이싱 구문을 조합하여 원하는 데이터 추출하기

# %%
subset=df.loc[:,["year","pop"]]
print(subset.head())
print("")
print(subset.tail())
print("")

subset_iloc=df.iloc[:,[2,4,-1]]
print(subset_iloc.head())
print("")
print(subset_iloc.tail())
# Out:
#    year       pop
# 0  1952   8425333
# 1  1957   9240934
# 2  1962  10267083
# 3  1967  11537966
# 4  1972  13079460
#
#       year       pop
# 1699  1987   9216418
# 1700  1992  10704340
# 1701  1997  11404948
# 1702  2002  11926563
# 1703  2007  12311143
#
#    year       pop   gdpPercap
# 0  1952   8425333  779.445314
# 1  1957   9240934  820.853030
# 2  1962  10267083  853.100710
# 3  1967  11537966  836.197138
# 4  1972  13079460  739.981106
#
#       year       pop   gdpPercap
# 1699  1987   9216418  706.157306
# 1700  1992  10704340  693.420786
# 1701  1997  11404948  792.449960
# 1702  2002  11926563  672.038623
# 1703  2007  12311143  469.709298

# %% [markdown]
# #
# iloc 속성과 range 메서드로 원하는 데이터 추출하기

# %%
small_range=list(range(5))
print(small_range)
print(type(small_range))
print("")

subset=df.iloc[:,small_range]
print(subset.head())
print("")

small_range=list(range(3,6))
print(small_range)
subset=df.iloc[:,small_range]
print(subset.head())
print("")

small_range=list(range(0,6,2))
print(small_range)
subset=df.iloc[:,small_range]
print(subset.head())
print(subset.tail())
print("")
# Out:
# [0, 1, 2, 3, 4]
# <class 'list'>
#
#        country continent  year  lifeExp       pop
# 0  Afghanistan      Asia  1952   28.801   8425333
# 1  Afghanistan      Asia  1957   30.332   9240934
# 2  Afghanistan      Asia  1962   31.997  10267083
# 3  Afghanistan      Asia  1967   34.020  11537966
# 4  Afghanistan      Asia  1972   36.088  13079460
#
# [3, 4, 5]
#    lifeExp       pop   gdpPercap
# 0   28.801   8425333  779.445314
# 1   30.332   9240934  820.853030
# 2   31.997  10267083  853.100710
# 3   34.020  11537966  836.197138
# 4   36.088  13079460  739.981106
#
# [0, 2, 4]
#        country  year       pop
# 0  Afghanistan  1952   8425333
# 1  Afghanistan  1957   9240934
# 2  Afghanistan  1962  10267083
# 3  Afghanistan  1967  11537966
# 4  Afghanistan  1972  13079460
#        country  year       pop
# 1699  Zimbabwe  1987   9216418
# 1700  Zimbabwe  1992  10704340
# 1701  Zimbabwe  1997  11404948
# 1702  Zimbabwe  2002  11926563
# 1703  Zimbabwe  2007  12311143

# %% [markdown]
# #
# 열 지정값에 파이썬 슬라이싱을 사용하여 원하는 데이터 추출하기

# %%
import pandas as pd
df=pd.read_csv("../data/gapminder.tsv", sep="\t")

subset=df.iloc[:,:3]
print(subset)
print("")
print(subset.head())
print(subset.tail())
print("")

subset=df.iloc[:,0:6:2]
print(subset.head())
print(subset.tail())
# Out:
#           country continent  year
# 0     Afghanistan      Asia  1952
# 1     Afghanistan      Asia  1957
# 2     Afghanistan      Asia  1962
# 3     Afghanistan      Asia  1967
# 4     Afghanistan      Asia  1972
# ...           ...       ...   ...
# 1699     Zimbabwe    Africa  1987
# 1700     Zimbabwe    Africa  1992
# 1701     Zimbabwe    Africa  1997
# 1702     Zimbabwe    Africa  2002
# 1703     Zimbabwe    Africa  2007
#
# [1704 rows x 3 columns]
#
#        country continent  year
# 0  Afghanistan      Asia  1952
# 1  Afghanistan      Asia  1957
# 2  Afghanistan      Asia  1962
# 3  Afghanistan      Asia  1967
# 4  Afghanistan      Asia  1972
#        country continent  year
# 1699  Zimbabwe    Africa  1987
# 1700  Zimbabwe    Africa  1992
# 1701  Zimbabwe    Africa  1997
# 1702  Zimbabwe    Africa  2002
# 1703  Zimbabwe    Africa  2007
#
#        country  year       pop
# 0  Afghanistan  1952   8425333
# 1  Afghanistan  1957   9240934
# 2  Afghanistan  1962  10267083
# ...

# %% [markdown]
# #
# loc, iloc 자유자재로 사용하기

# %%
#행, 렬을 입력하여 자유자재로 출력
print(df.iloc[[0,90,900],[0,3,5]])
print("")
print(df.loc[[0,90,900],["country","lifeExp","gdpPercap"]])
#해당 방식은 iloc이 아닌 loc만 반환
# Out:
#          country  lifeExp     gdpPercap
# 0    Afghanistan   28.801    779.445314
# 90       Bahrain   69.052  19211.147310
# 900        Libya   42.723   2387.548060
#
#          country  lifeExp     gdpPercap
# 0    Afghanistan   28.801    779.445314
# 90       Bahrain   69.052  19211.147310
# 900        Libya   42.723   2387.548060

# %% [markdown]
# #
# 그룹화한 데이터의 평균 구하기

# %%
print(df.groupby("year")["lifeExp"].mean())
print()
grouped_year_df=df.groupby("year")
print(type(grouped_year_df))
# 데이터프레임그룹 자료형

print()
print(grouped_year_df)
grouped_year_df_lifeExp=grouped_year_df['lifeExp']
print(type(grouped_year_df_lifeExp))
# 그룹화된 데이터프레임에서 열을 추출하면 그룹화된시리즈를 얻을 수 있다.
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64
#
# <class 'pandas.core.groupby.generic.DataFrameGroupBy'>
#
# ...
# <class 'pandas.core.groupby.generic.SeriesGroupBy'>

# %%
# 응용코드
multi_group_var=df.groupby(["year","continent"])[["lifeExp","gdpPercap"]].mean()
print(multi_group_var)
print()
print(type(multi_group_var))
# Out:
#                   lifeExp     gdpPercap
# year continent
# 1952 Africa     39.135500   1252.572466
#      Americas   53.279840   4079.062552
#      Asia       46.314394   5195.484004
#      Europe     64.408500   5661.057435
#      Oceania    69.255000  10298.085650
# 1957 Africa     41.266346   1385.236062
#      Americas   55.960280   4616.043733
#      Asia       49.318544   5787.732940
#      Europe     66.703067   6963.012816
#      Oceania    70.295000  11598.522455
# 1962 Africa     43.319442   1598.078825
#      Americas   58.398760   4901.541870
#      Asia       51.563223   5729.369625
#      Europe     68.539233   8365.486814
#      Oceania    71.085000  12696.452430
# 1967 Africa     45.334538   2050.363801
#      Americas   60.410920   5668.253496
#      Asia       54.663640   5971.173374
#      Europe     69.737600  10143.823757
#      Oceania    71.310000  14495.021790
# 1972 Africa     47.450942   2339.615674
#      Americas   62.394920   6491.334139
# ...

# %% [markdown]
# #
# 그룹화한 데이터의 개수 세어보기

# %%
print(df.groupby("continent")["country"].nunique())
# Out:
# continent
# Africa      52
# Americas    25
# Asia        33
# Europe      30
# Oceania      2
# Name: country, dtype: int64

# %% [markdown]
# #
# 그래프 만들기 >> 생략
